# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedQuresshi/Python-Lab-Tasks-1/blob/main/task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Student:
    def __init__(self, name):
        self.name = name

s = Student("Ahmed")

print("Namespace:", s.__dict__)
# Out:
# Namespace: {'name': 'Ahmed'}

# %%
def student_data(student_id, student_name=None, student_class=None):
    print("Student ID:", student_id)

    if student_name:
        print("Student Name:", student_name)
    if student_class:
        print("Class:", student_class)

student_data(101)
student_data(102, "Shaheer", "10th")
# Out:
# Student ID: 101
# Student ID: 102
# Student Name: Shaheer
# Class: 10th

# %%
class Student:
    pass

print(type(Student))
print(Student.__dict__.keys())
print(Student.__module__)
# Out:
# <class 'type'>
# dict_keys(['__module__', '__dict__', '__weakref__', '__doc__'])
# __main__

# %%
class Student:
    pass

class Marks:
    pass

s = Student()
m = Marks()

print(isinstance(s, Student))
print(isinstance(m, Marks))

print(issubclass(Student, object))
print(issubclass(Marks, object))
# Out:
# True
# True
# True
# True

# %%
class Student:
    def __init__(self, name, marks):
        self.name = name
        self.marks = marks

s = Student("Ahmed", 80)

print("Original:", s.name, s.marks)

s.name = "Azan"
s.marks = 90

print("Updated:", s.name, s.marks)
# Out:
# Original: Ahmed 80
# Updated: Azan 90

# %%
class Student:
    def __init__(self, student_id, student_name):
        self.student_id = student_id
        self.student_name = student_name

s = Student(101, "Shaheer")

s.student_class = "10th"
print("Before deletion:", s.__dict__)

del s.student_name
print("After deletion:", s.__dict__)
# Out:
# Before deletion: {'student_id': 101, 'student_name': 'Shaheer', 'student_class': '10th'}
# After deletion: {'student_id': 101, 'student_class': '10th'}

# %%
class Student:
    def __init__(self, student_id, student_name, student_class):
        self.student_id = student_id
        self.student_name = student_name
        self.student_class = student_class

    def display(self):
        for key, value in self.__dict__.items():
            print(key, ":", value)

s = Student(101, "Azan", "10th")
s.display()
# Out:
# student_id : 101
# student_name : Azan
# student_class : 10th

# %%
class Student:
    def __init__(self, student_id, student_name, student_class):
        self.student_id = student_id
        self.student_name = student_name
        self.student_class = student_class

    def display(self):
        print(f"ID: {self.student_id}, Name: {self.student_name}, Class: {self.student_class}")

student1 = Student(101, "Ahmed", "10th")
student2 = Student(102, "Shaheer", "9th")

student1.display()
student2.display()
# Out:
# ID: 101, Name: Ahmed, Class: 10th
# ID: 102, Name: Shaheer, Class: 9th

# %%
import sys

class Student:
    def __init__(self, name):
        self.name = name

s = Student("Azan")

print("Object size:", sys.getsizeof(s))
print("Dict size:", sys.getsizeof(s.__dict__))
# Out:
# Object size: 48
# Dict size: 296

# %%
import sys

class Student:
    __slots__ = ['name']

    def __init__(self, name):
        self.name = name

s = Student("Ahmed")

print("Memory with __slots__:", sys.getsizeof(s))
# Out:
# Memory with __slots__: 40

# %%
class Trapezoid:
    def __init__(self, a, b, height):
        self.a = a
        self.b = b
        self.height = height

    def area(self):
        return 0.5 * (self.a + self.b) * self.height


class Parallelogram:
    def __init__(self, base, height):
        self.base = base
        self.height = height

    def area(self):
        return self.base * self.height


t = Trapezoid(5, 7, 4)
p = Parallelogram(6, 5)

print("Trapezoid Area:", t.area())
print("Parallelogram Area:", p.area())
# Out:
# Trapezoid Area: 24.0
# Parallelogram Area: 30

# %%
t_area = 0.5 * (5 + 7) * 4
p_area = 6 * 5

if t_area > p_area:
    print("Trapezoid has larger area")
else:
    print("Parallelogram has larger area")
# Out:
# Parallelogram has larger area

# %%
areas = {
    "Trapezoid": 24,
    "Parallelogram": 30
}

print(areas)
# Out:
# {'Trapezoid': 24, 'Parallelogram': 30}

# %%
trapezoids = [(5,7,4), (6,8,5)]
parallelograms = [(5,4), (6,5)]

areas = {}

for i, (a,b,h) in enumerate(trapezoids):
    areas[f"Trapezoid_{i+1}"] = 0.5 * (a+b) * h

for i, (base,h) in enumerate(parallelograms):
    areas[f"Parallelogram_{i+1}"] = base * h

print(areas)
# Out:
# {'Trapezoid_1': 24.0, 'Trapezoid_2': 35.0, 'Parallelogram_1': 20, 'Parallelogram_2': 30}

# %%
areas = {
    "Trapezoid_1": 24,
    "Parallelogram_1": 30,
    "Trapezoid_2": 35
}

max_shape = max(areas, key=areas.get)

print("Max Shape:", max_shape)
print("Area:", areas[max_shape])
# Out:
# Max Shape: Trapezoid_2
# Area: 35
